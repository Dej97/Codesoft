# %%
import numpy as np
from sklearn.datasets import load_iris
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = load_iris()

# %%
X = data.data
y = data.target

# %%
X.shape,y.shape
# Out:
# ((150, 4), (150,))

# %%
y = np_utils.to_categorical(y,num_classes=3)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((135, 4), (15, 4), (135, 3), (15, 3))

# %%
model = Sequential()
model.add(Dense(4,input_dim = 4,activation='sigmoid'))
model.add(Dense(32,activation='sigmoid'))
model.add(Dense(64,activation='tanh'))
model.add(Dense(3,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 4)                 20
#
#  dense_20 (Dense)            (None, 32)                160
#
#  dense_21 (Dense)            (None, 64)                2112
#
#  dense_22 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 2,487
# Trainable params: 2,487
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf

# %%
tf.keras.utils.plot_model(model,  show_shapes=True)

# %%
model.compile(optimizer = 'adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,epochs=150,batch_size = 32)

# %%
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
model.predict([[1,2,5,1]])
# Out:
# 1/1 [==============================] - 0s 78ms/step
# array([[3.0949042e-05, 7.7948377e-02, 9.2202073e-01]], dtype=float32)

# %%
results = model.evaluate(X_test,y_test)
# Out:
# 1/1 [==============================] - 0s 131ms/step - loss: 0.1588 - accuracy: 0.9333

# %%
results
# Out:
# [0.15884384512901306, 0.9333333373069763]
